# %%
import warnings
warnings.filterwarnings('ignore')
import pandas as pd
import numpy as np
import seaborn as sn
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('bodyfat.csv')
df.head()
# Out:
#    Density  BodyFat  Age  Weight  Height  ...  Knee  Ankle  Biceps  Forearm  Wrist
# 0   1.0708     12.3   23  154.25   67.75  ...  37.3   21.9    32.0     27.4   17.1
# 1   1.0853      6.1   22  173.25   72.25  ...  37.3   23.4    30.5     28.9   18.2
# 2   1.0414     25.3   22  154.00   66.25  ...  38.9   24.0    28.8     25.2   16.6
# 3   1.0751     10.4   26  184.75   72.25  ...  37.3   22.8    32.4     29.4   18.2
# 4   1.0340     28.7   24  184.25   71.25  ...  42.2   24.0    32.2     27.7   17.7
#
# [5 rows x 15 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 252 entries, 0 to 251
# Data columns (total 15 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Density  252 non-null    float64
#  1   BodyFat  252 non-null    float64
#  2   Age      252 non-null    int64
#  3   Weight   252 non-null    float64
#  4   Height   252 non-null    float64
#  5   Neck     252 non-null    float64
#  6   Chest    252 non-null    float64
#  7   Abdomen  252 non-null    float64
#  8   Hip      252 non-null    float64
#  9   Thigh    252 non-null    float64
#  10  Knee     252 non-null    float64
#  11  Ankle    252 non-null    float64
#  12  Biceps   252 non-null    float64
#  13  Forearm  252 non-null    float64
#  14  Wrist    252 non-null    float64
# dtypes: float64(14), int64(1)
# memory usage: 29.7 KB

# %%
def plotdistplots(col):
    
    plt.figure(figsize=(12,5))
    sn.distplot(df['BodyFat'],color='magenta',hist=False,label='Bodyfat')
    sn.distplot(df[col],color = 'red',hist=False,label=col)
    plt.legend()
    plt.show()
    
    
cols = list(df.columns)
for i in cols:
    print(f'Distribution plots for {i} feature is shown ↓')
    plotdistplots(i)
    print("-"*100)
# Out:
# Distribution plots for Density feature is shown ↓
# ----------------------------------------------------------------------------------------------------
# Distribution plots for BodyFat feature is shown ↓
# ----------------------------------------------------------------------------------------------------
# Distribution plots for Age feature is shown ↓
# ----------------------------------------------------------------------------------------------------
# Distribution plots for Weight feature is shown ↓
# ----------------------------------------------------------------------------------------------------
# Distribution plots for Height feature is shown ↓
# ----------------------------------------------------------------------------------------------------
# Distribution plots for Neck feature is shown ↓
# ----------------------------------------------------------------------------------------------------
# Distribution plots for Chest feature is shown ↓
# ----------------------------------------------------------------------------------------------------
# Distribution plots for Abdomen feature is shown ↓
# ----------------------------------------------------------------------------------------------------
# Distribution plots for Hip feature is shown ↓
# ----------------------------------------------------------------------------------------------------
# Distribution plots for Thigh feature is shown ↓
# ----------------------------------------------------------------------------------------------------
# Distribution plots for Knee feature is shown ↓
# ----------------------------------------------------------------------------------------------------
# Distribution plots for Ankle feature is shown ↓
# ----------------------------------------------------------------------------------------------------
# Distribution plots for Biceps feature is shown ↓
# ----------------------------------------------------------------------------------------------------
# Distribution plots for Forearm feature is shown ↓
# ----------------------------------------------------------------------------------------------------
# Distribution plots for Wrist feature is shown ↓
# ----------------------------------------------------------------------------------------------------

# %%
import scipy.stats as stats

# %%
def drawplots(df,col):
    
    plt.figure(figsize=(15,7))
    plt.subplot(1,3,1)
    plt.hist(df[col],color='magenta')
    
    plt.subplot(1,3,2)
    stats.probplot(df[col],dist='norm',plot=plt)
    
    plt.subplot(1,3,3)
    sn.boxplot(df[col],color='magenta')
    
    
    plt.show()
    
    
cols = list(df.columns)
for i in range(len(cols)):
    
    print(f'Distribution plots for the feature {cols[i]} are shown ↓')
    
    drawplots(df,cols[i])
    
    print("="*100)
# Out:
# Distribution plots for the feature Density are shown ↓
# ====================================================================================================
# Distribution plots for the feature BodyFat are shown ↓
# ====================================================================================================
# Distribution plots for the feature Age are shown ↓
# ====================================================================================================
# Distribution plots for the feature Weight are shown ↓
# ====================================================================================================
# Distribution plots for the feature Height are shown ↓
# ====================================================================================================
# Distribution plots for the feature Neck are shown ↓
# ====================================================================================================
# Distribution plots for the feature Chest are shown ↓
# ====================================================================================================
# Distribution plots for the feature Abdomen are shown ↓
# ====================================================================================================
# Distribution plots for the feature Hip are shown ↓
# ====================================================================================================
# Distribution plots for the feature Thigh are shown ↓
# ====================================================================================================
# Distribution plots for the feature Knee are shown ↓
# ====================================================================================================
# Distribution plots for the feature Ankle are shown ↓
# ====================================================================================================
# Distribution plots for the feature Biceps are shown ↓
# ====================================================================================================
# Distribution plots for the feature Forearm are shown ↓
# ====================================================================================================
# Distribution plots for the feature Wrist are shown ↓
# ====================================================================================================

# %% [markdown]
# ### Checking for Outliers

# %%
upperlimit = []
lowerlimit = []
for i in df.columns:
    upperlimit.append(df[i].mean()+(df[i].std())*4)
    lowerlimit.append(df[i].mean()-(df[i].std())*4)

# %%
cols = list(df.columns)
j = 0
for i in range(len(cols)):
    
    temp = df.loc[(df[cols[i]]>upperlimit[j])&(df[cols[i]]<lowerlimit[j])]
    j+=1

# %%
temp
# Out:
# Empty DataFrame
# Columns: [Density, BodyFat, Age, Weight, Height, Neck, Chest, Abdomen, Hip, Thigh, Knee, Ankle, Biceps, Forearm, Wrist]
# Index: []

# %% [markdown]
# ## Using ExtraTrees Regressor for Feature Selection

# %%
data = df.copy()
test = data['BodyFat']
train = data.drop(['BodyFat'],axis=1)

# %%
from sklearn.ensemble import ExtraTreesRegressor
er = ExtraTreesRegressor()
er.fit(train,test)
# Out:
# ExtraTreesRegressor()

# %%
series = pd.Series(er.feature_importances_,index=train.columns)
series.nlargest(5).plot(kind = 'barh',color = 'green')

# %% [markdown]
# ## Using Mutual Information Gain for Feature Selection

# %%
from sklearn.feature_selection import mutual_info_regression
mr = mutual_info_regression(train,test)

# %%
plotdata = pd.Series(mr,index=train.columns)
plotdata.nlargest(5).plot(kind = 'barh',color = 'green')

# %% [markdown]
# ## Removing correlation

# %%
data
# Out:
#      Density  BodyFat  Age  Weight  Height  ...  Knee  Ankle  Biceps  Forearm  Wrist
# 0     1.0708     12.3   23  154.25   67.75  ...  37.3   21.9    32.0     27.4   17.1
# 1     1.0853      6.1   22  173.25   72.25  ...  37.3   23.4    30.5     28.9   18.2
# 2     1.0414     25.3   22  154.00   66.25  ...  38.9   24.0    28.8     25.2   16.6
# 3     1.0751     10.4   26  184.75   72.25  ...  37.3   22.8    32.4     29.4   18.2
# 4     1.0340     28.7   24  184.25   71.25  ...  42.2   24.0    32.2     27.7   17.7
# ..       ...      ...  ...     ...     ...  ...   ...    ...     ...      ...    ...
# 247   1.0736     11.0   70  134.25   67.00  ...  34.8   21.5    25.6     25.7   18.5
# 248   1.0236     33.6   72  201.00   69.75  ...  40.8   23.2    35.2     28.6   20.1
# 249   1.0328     29.3   72  186.75   66.00  ...  37.3   21.5    31.3     27.2   18.0
# 250   1.0399     26.0   72  190.75   70.50  ...  41.6   22.7    30.5     29.4   19.8
# 251   1.0271     31.9   74  207.50   70.00  ...  42.2   24.6    33.7     30.0   20.9
#
# [252 rows x 15 columns]

# %%
plt.figure(figsize=(15,7))
sn.heatmap(df.corr(),annot=True,cmap='plasma')

# %%
def correlation(df,threshold):
    
    colcor = set()
    
    cormat = df.corr()
    
    for i in range(len(cormat)):
        
        for j in range(i):
            
            '''
            for each cell get the value of that cell by .iloc[i][j],
            where i is the row and j is the col if that abs(value) is greater
            than the threshold,get the col_name and add it in the set
            
            '''
            
            if abs(cormat.iloc[i][j])>threshold:
                colname = cormat.columns[i]
                colcor.add(colname)
                
                
    return colcor


ans = correlation(train,threshold=0.85)

ans
# Out:
# {'Abdomen', 'Chest', 'Hip', 'Knee', 'Thigh'}

# %% [markdown]
# **From the above feature selection techniques we can say that the features recommended by the `Extra Trees Regressor` and the `mutual_information_gain` are correct and from the correlation map we get to observe the similar pattern we noticed that `Abdomen` and `Hip` are having similar features,they're having collinearity,same goes with knee and thigh,we can either keep any one of them and we noticed that the feature `Abdomen` gave more feature importance score in comparision to `Hip`,so i will be selecting that**

# %%
import statsmodels.api as sm
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
temp = data[list(data.columns)]
info = pd.DataFrame()
info['VIF'] = [variance_inflation_factor(temp.values,i) for i in range(temp.shape[1])]
info['Column'] = temp.columns
info
# Out:
#             VIF   Column
# 0   3695.622377  Density
# 1     33.845429  BodyFat
# 2     31.376101      Age
# 3   1238.097164   Weight
# 4    613.410514   Height
# 5   1081.965633     Neck
# 6   1374.457425    Chest
# 7   1332.624257  Abdomen
# 8   2933.636131      Hip
# 9   1017.257501    Thigh
# 10  1187.890413     Knee
# 11   356.293529    Ankle
# 12   419.391664   Biceps
# 13   454.571766  Forearm
# 14  1349.973920    Wrist

# %%
cols1 = list(series.nlargest(5).index)
cols2 = list(plotdata.nlargest(5).index)

cols1,cols2
# Out:
# (['Density', 'Abdomen', 'Chest', 'Hip', 'Weight'],
#  ['Density', 'Abdomen', 'Chest', 'Hip', 'Weight'])

# %% [markdown]
# **We'll go with the `Weight and Hip` method,as `Hip` and `Thigh` are very much related,so we'll select the cols1 features and drop every other feature,if that doesn't produce any further importance we will try with some other feature**

# %%
totrain = train[cols1]
totrain.head()
# Out:
#    Density  Abdomen  Chest    Hip  Weight
# 0   1.0708     85.2   93.1   94.5  154.25
# 1   1.0853     83.0   93.6   98.7  173.25
# 2   1.0414     87.9   95.8   99.2  154.00
# 3   1.0751     86.4  101.8  101.2  184.75
# 4   1.0340    100.0   97.3  101.9  184.25

# %%
from sklearn.model_selection import train_test_split,RandomizedSearchCV
from sklearn import metrics
from sklearn import tree
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.svm import SVR
from sklearn.linear_model import LinearRegression,Lasso,Ridge

# %%
X_train, X_test, y_train, y_test = train_test_split(totrain,test,test_size=0.2)
X_train.shape,X_test.shape
# Out:
# ((201, 5), (51, 5))

# %%
reg = DecisionTreeRegressor()
reg.fit(X_train,y_train)
plt.figure(figsize=(15,7))
tree.plot_tree(reg,filled=True)
# Out:
# [Text(398.62234669811323, 364.66499999999996, 'X[0] <= 1.056\nsquared_error = 71.135\nsamples = 201\nvalue = 18.914'),
#  Text(161.1049528301887, 332.955, 'X[0] <= 1.036\nsquared_error = 26.042\nsamples = 99\nvalue = 25.923'),
#  Text(51.98349056603774, 301.245, 'X[0] <= 1.014\nsquared_error = 14.649\nsamples = 32\nvalue = 31.934'),
#  Text(26.32075471698113, 269.53499999999997, 'X[4] <= 205.375\nsquared_error = 13.69\nsamples = 2\nvalue = 43.8'),
#  Text(22.81132075471698, 237.825, 'squared_error = 0.0\nsamples = 1\nvalue = 40.1'),
#  Text(29.830188679245285, 237.825, 'squared_error = 0.0\nsamples = 1\nvalue = 47.5'),
#  Text(77.64622641509435, 269.53499999999997, 'X[0] <= 1.029\nsquared_error = 4.7\nsamples = 30\nvalue = 31.143'),
#  Text(36.84905660377358, 237.825, 'X[0] <= 1.025\nsquared_error = 1.849\nsamples = 14\nvalue = 33.107'),
#  Text(15.79245283018868, 206.115, 'X[2] <= 117.25\nsquared_error = 0.276\nsamples = 6\nvalue = 34.567'),
#  Text(7.018867924528302, 174.405, 'X[4] <= 214.625\nsquared_error = 0.122\nsamples = 2\nvalue = 33.95'),
#  Text(3.509433962264151, 142.695, 'squared_error = 0.0\nsamples = 1\nvalue = 33.6'),
#  Text(10.528301886792454, 142.695, 'squared_error = -0.0\nsamples = 1\nvalue = 34.3'),
#  Text(24.566037735849058, 174.405, 'X[0] <= 1.021\nsquared_error = 0.067\nsamples = 4\nvalue = 34.875'),
#  Text(17.547169811320757, 142.695, 'X[4] <= 293.825\nsquared_error = 0.01\nsamples = 2\nvalue = 35.1'),
#  Text(14.037735849056604, 110.98500000000001, 'squared_error = 0.0\nsamples = 1\nvalue = 35.0'),
#  Text(21.056603773584907, 110.98500000000001, 'squared_error = -0.0\nsamples = 1\nvalue = 35.2'),
#  Text(31.58490566037736, 142.695, 'X[4] <= 242.875\nsquared_error = 0.023\nsamples = 2\nvalue = 34.65'),
#  Text(28.07547169811321, 110.98500000000001, 'squared_error = 0.0\nsamples = 1\nvalue = 34.8'),
#  Text(35.09433962264151, 110.98500000000001, 'squared_error = 0.0\nsamples = 1\nvalue = 34.5'),
#  Text(57.905660377358494, 206.115, 'X[0] <= 1.027\nsquared_error = 0.234\nsamples = 8\nvalue = 32.013'),
#  Text(49.132075471698116, 174.405, 'X[2] <= 115.9\nsquared_error = 0.042\nsamples = 3\nvalue = 32.567'),
#  Text(45.62264150943396, 142.695, 'X[2] <= 108.75\nsquared_error = 0.01\nsamples = 2\nvalue = 32.7'),
#  Text(42.113207547169814, 110.98500000000001, 'squared_error = 0.0\nsamples = 1\nvalue = 32.8'),
#  Text(49.132075471698116, 110.98500000000001, 'squared_error = -0.0\nsamples = 1\nvalue = 32.6'),
#  Text(52.64150943396226, 142.695, 'squared_error = -0.0\nsamples = 1\nvalue = 32.3'),
#  Text(66.67924528301887, 174.405, 'X[0] <= 1.027\nsquared_error = 0.054\nsamples = 5\nvalue = 31.68'),
#  Text(59.66037735849057, 142.695, 'X[1] <= 106.4\nsquared_error = 0.002\nsamples = 2\nvalue = 31.95'),
#  Text(56.15094339622642, 110.98500000000001, 'squared_error = 0.0\nsamples = 1\nvalue = 32.0'),
#  Text(63.16981132075472, 110.98500000000001, 'squared_error = 0.0\nsamples = 1\nvalue = 31.9'),
#  Text(73.69811320754717, 142.695, 'X[2] <= 105.5\nsquared_error = 0.007\nsamples = 3\nvalue = 31.5'),
#  Text(70.18867924528303, 110.98500000000001, 'squared_error = 0.0\nsamples = 1\nvalue = 31.4'),
#  Text(77.20754716981132, 110.98500000000001, 'X[4] <= 209.75\nsquared_error = 0.002\nsamples = 2\nvalue = 31.55'),
#  Text(73.69811320754717, 79.27500000000003, 'squared_error = 0.0\nsamples = 1\nvalue = 31.5'),
#  Text(80.71698113207547, 79.27500000000003, 'squared_error = -0.0\nsamples = 1\nvalue = 31.6'),
#  Text(118.4433962264151, 237.825, 'X[0] <= 1.032\nsquared_error = 0.868\nsamples = 16\nvalue = 29.425'),
#  Text(96.50943396226415, 206.115, 'X[0] <= 1.031\nsquared_error = 0.242\nsamples = 8\nvalue = 30.225'),
#  Text(84.22641509433963, 174.405, 'X[0] <= 1.029\nsquared_error = 0.109\nsamples = 3\nvalue = 30.767'),
#  Text(80.71698113207547, 142.695, 'squared_error = 0.0\nsamples = 1\nvalue = 31.2'),
#  Text(87.73584905660378, 142.695, 'X[0] <= 1.03\nsquared_error = 0.023\nsamples = 2\nvalue = 30.55'),
#  Text(84.22641509433963, 110.98500000000001, 'squared_error = 0.0\nsamples = 1\nvalue = 30.7'),
#  Text(91.24528301886792, 110.98500000000001, 'squared_error = 0.0\nsamples = 1\nvalue = 30.4'),
#  Text(108.79245283018868, 174.405, 'X[0] <= 1.031\nsquared_error = 0.04\nsamples = 5\nvalue = 29.9'),
#  Text(101.77358490566039, 142.695, 'X[4] <= 199.5\nsquared_error = 0.01\nsamples = 2\nvalue = 30.1'),
#  Text(98.26415094339623, 110.98500000000001, 'squared_error = 0.0\nsamples = 1\nvalue = 30.0'),
#  Text(105.28301886792453, 110.98500000000001, 'squared_error = -0.0\nsamples = 1\nvalue = 30.2'),
#  Text(115.81132075471699, 142.695, 'X[0] <= 1.032\nsquared_error = 0.016\nsamples = 3\nvalue = 29.767'),
#  Text(112.30188679245283, 110.98500000000001, 'X[4] <= 184.25\nsquared_error = 0.003\nsamples = 2\nvalue = 29.85'),
#  Text(108.79245283018868, 79.27500000000003, 'squared_error = 0.0\nsamples = 1\nvalue = 29.8'),
#  Text(115.81132075471699, 79.27500000000003, 'squared_error = -0.0\nsamples = 1\nvalue = 29.9'),
#  Text(119.32075471698114, 110.98500000000001, 'squared_error = 0.0\nsamples = 1\nvalue = 29.6'),
#  Text(140.37735849056605, 206.115, 'X[0] <= 1.034\nsquared_error = 0.214\nsamples = 8\nvalue = 28.625'),
#  Text(133.35849056603774, 174.405, 'X[0] <= 1.034\nsquared_error = 0.05\nsamples = 5\nvalue = 28.94'),
#  Text(129.8490566037736, 142.695, 'X[1] <= 108.8\nsquared_error = 0.02\nsamples = 3\nvalue = 29.1'),
#  Text(126.33962264150944, 110.98500000000001, 'squared_error = 0.0\nsamples = 2\nvalue = 29.0'),
#  Text(133.35849056603774, 110.98500000000001, 'squared_error = 0.0\nsamples = 1\nvalue = 29.3'),
#  Text(136.8679245283019, 142.695, 'squared_error = -0.0\nsamples = 2\nvalue = 28.7'),
#  Text(147.39622641509433, 174.405, 'X[1] <= 99.0\nsquared_error = 0.047\nsamples = 3\nvalue = 28.1'),
#  Text(143.8867924528302, 142.695, 'squared_error = 0.0\nsamples = 1\nvalue = 28.4'),
#  Text(150.9056603773585, 142.695, 'X[4] <= 203.875\nsquared_error = 0.002\nsamples = 2\nvalue = 27.95'),
#  Text(147.39622641509433, 110.98500000000001, 'squared_error = 0.0\nsamples = 1\nvalue = 28.0'),
#  Text(154.41509433962264, 110.98500000000001, 'squared_error = -0.0\nsamples = 1\nvalue = 27.9'),
#  Text(270.22641509433964, 301.245, 'X[0] <= 1.046\nsquared_error = 5.983\nsamples = 67\nvalue = 23.052'),
#  Text(207.05660377358492, 269.53499999999997, 'X[0] <= 1.041\nsquared_error = 1.142\nsamples = 26\nvalue = 25.781'),
#  Text(184.24528301886792, 237.825, 'X[0] <= 1.039\nsquared_error = 0.308\nsamples = 14\nvalue = 26.629'),
#  Text(175.47169811320757, 206.115, 'X[0] <= 1.038\nsquared_error = 0.061\nsamples = 9\nvalue = 27.011'),
#  Text(168.45283018867926, 174.405, 'X[0] <= 1.038\nsquared_error = 0.016\nsamples = 6\nvalue = 27.167'),
#  Text(164.9433962264151, 142.695, 'X[1] <= 105.0\nsquared_error = 0.003\nsamples = 4\nvalue = 27.25'),
#  Text(161.43396226415095, 110.98500000000001, 'squared_error = 0.0\nsamples = 2\nvalue = 27.2'),
#  Text(168.45283018867926, 110.98500000000001, 'X[2] <= 114.5\nsquared_error = 0.0\nsamples = 2\nvalue = 27.3'),
#  Text(164.9433962264151, 79.27500000000003, 'squared_error = 0.0\nsamples = 1\nvalue = 27.3'),
#  Text(171.9622641509434, 79.27500000000003, 'squared_error = 0.0\nsamples = 1\nvalue = 27.3'),
#  Text(171.9622641509434, 142.695, 'squared_error = 0.0\nsamples = 2\nvalue = 27.0'),
#  Text(182.49056603773585, 174.405, 'X[0] <= 1.038\nsquared_error = 0.007\nsamples = 3\nvalue = 26.7'),
#  Text(178.9811320754717, 142.695, 'squared_error = 0.0\nsamples = 1\nvalue = 26.8'),
#  Text(186.0, 142.695, 'X[2] <= 99.8\nsquared_error = 0.003\nsamples = 2\nvalue = 26.65'),
#  Text(182.49056603773585, 110.98500000000001, 'squared_error = 0.0\nsamples = 1\nvalue = 26.6'),
#  Text(189.50943396226415, 110.98500000000001, 'squared_error = 0.0\nsamples = 1\nvalue = 26.7'),
#  Text(193.0188679245283, 206.115, 'X[2] <= 106.8\nsquared_error = 0.014\nsamples = 5\nvalue = 25.94'),
#  Text(189.50943396226415, 174.405, 'squared_error = 0.0\nsamples = 2\nvalue = 25.8'),
#  Text(196.52830188679246, 174.405, 'X[0] <= 1.04\nsquared_error = 0.002\nsamples = 3\nvalue = 26.033'),
#  Text(193.0188679245283, 142.695, 'squared_error = 0.0\nsamples = 1\nvalue = 26.1'),
#  Text(200.03773584905662, 142.695, 'X[1] <= 105.85\nsquared_error = 0.0\nsamples = 2\nvalue = 26.0'),
#  Text(196.52830188679246, 110.98500000000001, 'squared_error = 0.0\nsamples = 1\nvalue = 26.0'),
#  Text(203.54716981132077, 110.98500000000001, 'squared_error = 0.0\nsamples = 1\nvalue = 26.0'),
#  Text(229.8679245283019, 237.825, 'X[0] <= 1.043\nsquared_error = 0.297\nsamples = 12\nvalue = 24.792'),
#  Text(217.58490566037736, 206.115, 'X[0] <= 1.042\nsquared_error = 0.053\nsamples = 7\nvalue = 25.186'),
#  Text(210.56603773584905, 174.405, 'X[0] <= 1.041\nsquared_error = 0.01\nsamples = 5\nvalue = 25.32'),
#  Text(207.05660377358492, 142.695, 'squared_error = 0.0\nsamples = 1\nvalue = 25.5'),
#  Text(214.0754716981132, 142.695, 'X[0] <= 1.041\nsquared_error = 0.002\nsamples = 4\nvalue = 25.275'),
#  Text(210.56603773584905, 110.98500000000001, 'X[3] <= 100.3\nsquared_error = 0.0\nsamples = 3\nvalue = 25.3'),
#  Text(207.05660377358492, 79.27500000000003, 'squared_error = 0.0\nsamples = 1\nvalue = 25.3'),
#  Text(214.0754716981132, 79.27500000000003, 'squared_error = -0.0\nsamples = 2\nvalue = 25.3'),
#  Text(217.58490566037736, 110.98500000000001, 'squared_error = 0.0\nsamples = 1\nvalue = 25.2'),
#  Text(224.60377358490567, 174.405, 'X[2] <= 101.3\nsquared_error = 0.003\nsamples = 2\nvalue = 24.85'),
#  Text(221.0943396226415, 142.695, 'squared_error = 0.0\nsamples = 1\nvalue = 24.9'),
#  Text(228.11320754716982, 142.695, 'squared_error = -0.0\nsamples = 1\nvalue = 24.8'),
#  Text(242.1509433962264, 206.115, 'X[0] <= 1.044\nsquared_error = 0.118\nsamples = 5\nvalue = 24.24'),
#  Text(238.64150943396228, 174.405, 'X[0] <= 1.043\nsquared_error = 0.02\nsamples = 4\nvalue = 24.4'),
#  Text(235.13207547169813, 142.695, 'squared_error = 0.0\nsamples = 1\nvalue = 24.6'),
#  Text(242.1509433962264, 142.695, 'X[3] <= 104.65\nsquared_error = 0.009\nsamples = 3\nvalue = 24.333'),
#  Text(238.64150943396228, 110.98500000000001, 'squared_error = 0.0\nsamples = 2\nvalue = 24.4'),
#  Text(245.66037735849056, 110.98500000000001, 'squared_error = 0.0\nsamples = 1\nvalue = 24.2'),
#  Text(245.66037735849056, 174.405, 'squared_error = 0.0\nsamples = 1\nvalue = 23.6'),
#  Text(333.39622641509436, 269.53499999999997, 'X[0] <= 1.05\nsquared_error = 1.338\nsamples = 41\nvalue = 21.322'),
#  Text(284.26415094339626, 237.825, 'X[0] <= 1.048\nsquared_error = 0.316\nsamples = 20\nvalue = 22.325'),
#  Text(261.45283018867923, 206.115, 'X[3] <= 94.45\nsquared_error = 0.104\nsamples = 8\nvalue = 22.888'),
#  Text(252.67924528301887, 174.405, 'X[1] <= 90.3\nsquared_error = 0.062\nsamples = 2\nvalue = 23.35'),
#  Text(249.16981132075472, 142.695, 'squared_error = 0.0\nsamples = 1\nvalue = 23.6'),
#  Text(256.188679245283, 142.695, 'squared_error = 0.0\nsamples = 1\nvalue = 23.1'),
#  Text(270.22641509433964, 174.405, 'X[0] <= 1.047\nsquared_error = 0.022\nsamples = 6\nvalue = 22.733'),
#  Text(263.20754716981133, 142.695, 'X[2] <= 94.8\nsquared_error = 0.002\nsamples = 3\nvalue = 22.867'),
#  Text(259.6981132075472, 110.98500000000001, 'squared_error = 0.0\nsamples = 1\nvalue = 22.8'),
#  Text(266.7169811320755, 110.98500000000001, 'squared_error = -0.0\nsamples = 2\nvalue = 22.9'),
#  Text(277.24528301886795, 142.695, 'X[0] <= 1.048\nsquared_error = 0.007\nsamples = 3\nvalue = 22.6'),
#  Text(273.7358490566038, 110.98500000000001, 'X[3] <= 99.35\nsquared_error = 0.003\nsamples = 2\nvalue = 22.65'),
#  Text(270.22641509433964, 79.27500000000003, 'squared_error = 0.0\nsamples = 1\nvalue = 22.7'),
#  Text(277.24528301886795, 79.27500000000003, 'squared_error = 0.0\nsamples = 1\nvalue = 22.6'),
#  Text(280.7547169811321, 110.98500000000001, 'squared_error = 0.0\nsamples = 1\nvalue = 22.5'),
#  Text(307.07547169811323, 206.115, 'X[0] <= 1.049\nsquared_error = 0.106\nsamples = 12\nvalue = 21.95'),
#  Text(298.3018867924528, 174.405, 'X[0] <= 1.048\nsquared_error = 0.011\nsamples = 7\nvalue = 22.2'),
#  Text(291.2830188679245, 142.695, 'X[0] <= 1.048\nsquared_error = 0.002\nsamples = 2\nvalue = 22.35'),
#  Text(287.7735849056604, 110.98500000000001, 'squared_error = 0.0\nsamples = 1\nvalue = 22.3'),
#  Text(294.79245283018867, 110.98500000000001, 'squared_error = -0.0\nsamples = 1\nvalue = 22.4'),
#  Text(305.3207547169811, 142.695, 'X[2] <= 101.65\nsquared_error = 0.002\nsamples = 5\nvalue = 22.14'),
#  Text(301.811320754717, 110.98500000000001, 'X[2] <= 95.4\nsquared_error = 0.0\nsamples = 3\nvalue = 22.1'),
#  Text(298.3018867924528, 79.27500000000003, 'squared_error = 0.0\nsamples = 1\nvalue = 22.1'),
#  Text(305.3207547169811, 79.27500000000003, 'squared_error = -0.0\nsamples = 2\nvalue = 22.1'),
#  Text(308.8301886792453, 110.98500000000001, 'squared_error = -0.0\nsamples = 2\nvalue = 22.2'),
#  Text(315.8490566037736, 174.405, 'X[0] <= 1.05\nsquared_error = 0.028\nsamples = 5\nvalue = 21.6'),
#  Text(312.33962264150944, 142.695, 'squared_error = 0.0\nsamples = 2\nvalue = 21.8'),
#  Text(319.35849056603774, 142.695, 'X[2] <= 97.1\nsquared_error = 0.002\nsamples = 3\nvalue = 21.467'),
#  Text(315.8490566037736, 110.98500000000001, 'squared_error = -0.0\nsamples = 2\nvalue = 21.5'),
#  Text(322.8679245283019, 110.98500000000001, 'squared_error = 0.0\nsamples = 1\nvalue = 21.4'),
#  Text(382.52830188679246, 237.825, 'X[0] <= 1.053\nsquared_error = 0.441\nsamples = 21\nvalue = 20.367'),
#  Text(364.9811320754717, 206.115, 'X[0] <= 1.052\nsquared_error = 0.149\nsamples = 16\nvalue = 20.681'),
#  Text(350.94339622641513, 174.405, 'X[0] <= 1.051\nsquared_error = 0.039\nsamples = 8\nvalue = 21.025'),
#  Text(336.9056603773585, 142.695, 'X[3] <= 104.75\nsquared_error = 0.027\nsamples = 4\nvalue = 21.175'),
#  Text(329.8867924528302, 110.98500000000001, 'X[2] <= 100.0\nsquared_error = 0.003\nsamples = 2\nvalue = 21.25'),
#  Text(326.37735849056605, 79.27500000000003, 'squared_error = 0.0\nsamples = 1\nvalue = 21.3'),
#  Text(333.39622641509436, 79.27500000000003, 'squared_error = 0.0\nsamples = 1\nvalue = 21.2'),
#  Text(343.9245283018868, 110.98500000000001, 'X[1] <= 97.45\nsquared_error = 0.04\nsamples = 2\nvalue = 21.1'),
#  Text(340.41509433962267, 79.27500000000003, 'squared_error = 0.0\nsamples = 1\nvalue = 20.9'),
#  Text(347.433962264151, 79.27500000000003, 'squared_error = -0.0\nsamples = 1\nvalue = 21.3'),
#  Text(364.9811320754717, 142.695, 'X[0] <= 1.051\nsquared_error = 0.007\nsamples = 4\nvalue = 20.875'),
#  Text(357.9622641509434, 110.98500000000001, 'X[4] <= 181.5\nsquared_error = 0.002\nsamples = 2\nvalue = 20.95'),
#  Text(354.45283018867923, 79.27500000000003, 'squared_error = 0.0\nsamples = 1\nvalue = 20.9'),
#  Text(361.47169811320754, 79.27500000000003, 'squared_error = 0.0\nsamples = 1\nvalue = 21.0'),
#  Text(372.0, 110.98500000000001, 'X[1] <= 92.55\nsquared_error = 0.0\nsamples = 2\nvalue = 20.8'),
#  Text(368.49056603773585, 79.27500000000003, 'squared_error = 0.0\nsamples = 1\nvalue = 20.8'),
#  Text(375.50943396226415, 79.27500000000003, 'squared_error = 0.0\nsamples = 1\nvalue = 20.8'),
#  Text(379.0188679245283, 174.405, 'X[1] <= 91.0\nsquared_error = 0.022\nsamples = 8\nvalue = 20.338'),
#  Text(375.50943396226415, 142.695, 'squared_error = 0.0\nsamples = 2\nvalue = 20.1'),
#  Text(382.52830188679246, 142.695, 'X[0] <= 1.052\nsquared_error = 0.005\nsamples = 6\nvalue = 20.417'),
#  Text(379.0188679245283, 110.98500000000001, 'squared_error = 0.0\nsamples = 2\nvalue = 20.5'),
#  Text(386.0377358490566, 110.98500000000001, 'X[0] <= 1.052\nsquared_error = 0.002\nsamples = 4\nvalue = 20.375'),
#  Text(382.52830188679246, 79.27500000000003, 'squared_error = -0.0\nsamples = 3\nvalue = 20.4'),
#  Text(389.54716981132077, 79.27500000000003, 'squared_error = -0.0\nsamples = 1\nvalue = 20.3'),
#  Text(400.07547169811323, 206.115, 'X[0] <= 1.054\nsquared_error = 0.046\nsamples = 5\nvalue = 19.36'),
#  Text(393.0566037735849, 174.405, 'X[1] <= 89.1\nsquared_error = 0.01\nsamples = 2\nvalue = 19.6'),
#  Text(389.54716981132077, 142.695, 'squared_error = 0.0\nsamples = 1\nvalue = 19.5'),
#  Text(396.5660377358491, 142.695, 'squared_error = -0.0\nsamples = 1\nvalue = 19.7'),
#  Text(407.09433962264154, 174.405, 'X[3] <= 104.25\nsquared_error = 0.007\nsamples = 3\nvalue = 19.2'),
#  Text(403.5849056603774, 142.695, 'squared_error = 0.0\nsamples = 1\nvalue = 19.3'),
#  Text(410.6037735849057, 142.695, 'X[2] <= 102.65\nsquared_error = 0.003\nsamples = 2\nvalue = 19.15'),
#  Text(407.09433962264154, 110.98500000000001, 'squared_error = 0.0\nsamples = 1\nvalue = 19.2'),
#  Text(414.11320754716985, 110.98500000000001, 'squared_error = 0.0\nsamples = 1\nvalue = 19.1'),
#  Text(636.1397405660377, 332.955, 'X[0] <= 1.072\nsquared_error = 20.947\nsamples = 102\nvalue = 12.112'),
#  Text(523.0153301886793, 301.245, 'X[0] <= 1.063\nsquared_error = 6.326\nsamples = 56\nvalue = 15.391'),
#  Text(474.6509433962264, 269.53499999999997, 'X[0] <= 1.059\nsquared_error = 0.748\nsamples = 27\nvalue = 17.407'),
#  Text(443.94339622641513, 237.825, 'X[1] <= 91.55\nsquared_error = 0.144\nsamples = 13\nvalue = 18.185'),
#  Text(428.1509433962264, 206.115, 'X[0] <= 1.058\nsquared_error = 0.053\nsamples = 6\nvalue = 17.85'),
#  Text(421.1320754716981, 174.405, 'X[2] <= 95.45\nsquared_error = 0.002\nsamples = 3\nvalue = 18.067'),
#  Text(417.62264150943395, 142.695, 'squared_error = 0.0\nsamples = 1\nvalue = 18.0'),
#  Text(424.64150943396226, 142.695, 'squared_error = 0.0\nsamples = 2\nvalue = 18.1'),
#  Text(435.1698113207547, 174.405, 'X[1] <= 89.8\nsquared_error = 0.009\nsamples = 3\nvalue = 17.633'),
#  Text(431.66037735849056, 142.695, 'squared_error = -0.0\nsamples = 2\nvalue = 17.7'),
#  Text(438.6792452830189, 142.695, 'squared_error = 0.0\nsamples = 1\nvalue = 17.5'),
#  Text(459.7358490566038, 206.115, 'X[0] <= 1.057\nsquared_error = 0.045\nsamples = 7\nvalue = 18.471'),
#  Text(449.20754716981133, 174.405, 'X[0] <= 1.056\nsquared_error = 0.007\nsamples = 3\nvalue = 18.7'),
#  Text(445.6981132075472, 142.695, 'squared_error = 0.0\nsamples = 1\nvalue = 18.8'),
#  Text(452.7169811320755, 142.695, 'X[3] <= 98.95\nsquared_error = 0.002\nsamples = 2\nvalue = 18.65'),
#  Text(449.20754716981133, 110.98500000000001, 'squared_error = 0.0\nsamples = 1\nvalue = 18.6'),
#  Text(456.22641509433964, 110.98500000000001, 'squared_error = 0.0\nsamples = 1\nvalue = 18.7'),
#  Text(470.26415094339626, 174.405, 'X[0] <= 1.057\nsquared_error = 0.005\nsamples = 4\nvalue = 18.3'),
#  Text(466.7547169811321, 142.695, 'X[0] <= 1.057\nsquared_error = 0.002\nsamples = 3\nvalue = 18.333'),
#  Text(463.24528301886795, 110.98500000000001, 'squared_error = 0.0\nsamples = 1\nvalue = 18.4'),
#  Text(470.26415094339626, 110.98500000000001, 'squared_error = 0.0\nsamples = 2\nvalue = 18.3'),
#  Text(473.7735849056604, 142.695, 'squared_error = 0.0\nsamples = 1\nvalue = 18.2'),
#  Text(505.35849056603774, 237.825, 'X[0] <= 1.061\nsquared_error = 0.227\nsamples = 14\nvalue = 16.686'),
#  Text(491.3207547169811, 206.115, 'X[0] <= 1.06\nsquared_error = 0.036\nsamples = 6\nvalue = 17.15'),
#  Text(484.3018867924528, 174.405, 'X[4] <= 161.875\nsquared_error = 0.002\nsamples = 3\nvalue = 17.333'),
#  Text(480.7924528301887, 142.695, 'squared_error = 0.0\nsamples = 1\nvalue = 17.4'),
#  Text(487.811320754717, 142.695, 'squared_error = -0.0\nsamples = 2\nvalue = 17.3'),
#  Text(498.33962264150944, 174.405, 'X[4] <= 201.25\nsquared_error = 0.002\nsamples = 3\nvalue = 16.967'),
#  Text(494.8301886792453, 142.695, 'squared_error = 0.0\nsamples = 2\nvalue = 17.0'),
#  Text(501.8490566037736, 142.695, 'squared_error = -0.0\nsamples = 1\nvalue = 16.9'),
#  Text(519.3962264150944, 206.115, 'X[0] <= 1.062\nsquared_error = 0.087\nsamples = 8\nvalue = 16.337'),
#  Text(512.377358490566, 174.405, 'X[3] <= 93.9\nsquared_error = 0.006\nsamples = 5\nvalue = 16.56'),
#  Text(508.8679245283019, 142.695, 'squared_error = 0.0\nsamples = 1\nvalue = 16.7'),
#  Text(515.8867924528302, 142.695, 'X[3] <= 100.05\nsquared_error = 0.002\nsamples = 4\nvalue = 16.525'),
#  Text(512.377358490566, 110.98500000000001, 'squared_error = 0.0\nsamples = 2\nvalue = 16.5'),
#  Text(519.3962264150944, 110.98500000000001, 'X[4] <= 210.25\nsquared_error = 0.003\nsamples = 2\nvalue = 16.55'),
#  Text(515.8867924528302, 79.27500000000003, 'squared_error = 0.0\nsamples = 1\nvalue = 16.6'),
#  Text(522.9056603773585, 79.27500000000003, 'squared_error = 0.0\nsamples = 1\nvalue = 16.5'),
#  Text(526.4150943396227, 174.405, 'X[3] <= 102.55\nsquared_error = 0.002\nsamples = 3\nvalue = 15.967'),
#  Text(522.9056603773585, 142.695, 'squared_error = 0.0\nsamples = 2\nvalue = 16.0'),
#  Text(529.9245283018868, 142.695, 'squared_error = 0.0\nsamples = 1\nvalue = 15.9'),
#  Text(571.3797169811321, 269.53499999999997, 'X[0] <= 1.066\nsquared_error = 4.209\nsamples = 29\nvalue = 13.514'),
#  Text(549.2264150943396, 237.825, 'X[0] <= 1.064\nsquared_error = 0.056\nsamples = 9\nvalue = 14.956'),
#  Text(536.9433962264151, 206.115, 'X[0] <= 1.064\nsquared_error = 0.016\nsamples = 3\nvalue = 15.233'),
#  Text(533.433962264151, 174.405, 'squared_error = 0.0\nsamples = 1\nvalue = 15.4'),
#  Text(540.4528301886793, 174.405, 'X[1] <= 83.85\nsquared_error = 0.002\nsamples = 2\nvalue = 15.15'),
#  Text(536.9433962264151, 142.695, 'squared_error = 0.0\nsamples = 1\nvalue = 15.1'),
#  Text(543.9622641509434, 142.695, 'squared_error = 0.0\nsamples = 1\nvalue = 15.2'),
#  Text(561.5094339622642, 206.115, 'X[0] <= 1.065\nsquared_error = 0.018\nsamples = 6\nvalue = 14.817'),
#  Text(554.4905660377359, 174.405, 'X[0] <= 1.065\nsquared_error = 0.005\nsamples = 4\nvalue = 14.9'),
#  Text(550.9811320754717, 142.695, 'squared_error = 0.0\nsamples = 1\nvalue = 15.0'),
#  Text(558.0, 142.695, 'X[0] <= 1.065\nsquared_error = 0.002\nsamples = 3\nvalue = 14.867'),
#  Text(554.4905660377359, 110.98500000000001, 'squared_error = 0.0\nsamples = 2\nvalue = 14.9'),
#  Text(561.5094339622642, 110.98500000000001, 'squared_error = 0.0\nsamples = 1\nvalue = 14.8'),
#  Text(568.5283018867925, 174.405, 'X[2] <= 101.55\nsquared_error = 0.002\nsamples = 2\nvalue = 14.65'),
#  Text(565.0188679245283, 142.695, 'squared_error = 0.0\nsamples = 1\nvalue = 14.7'),
#  Text(572.0377358490566, 142.695, 'squared_error = 0.0\nsamples = 1\nvalue = 14.6'),
#  Text(593.5330188679245, 237.825, 'X[0] <= 1.067\nsquared_error = 4.722\nsamples = 20\nvalue = 12.865'),
#  Text(590.0235849056604, 206.115, 'squared_error = 0.0\nsamples = 1\nvalue = 5.6'),
#  Text(597.0424528301887, 206.115, 'X[0] <= 1.067\nsquared_error = 2.047\nsamples = 19\nvalue = 13.247'),
#  Text(582.566037735849, 174.405, 'X[4] <= 162.125\nsquared_error = 4.84\nsamples = 2\nvalue = 16.3'),
#  Text(579.0566037735849, 142.695, 'squared_error = 0.0\nsamples = 1\nvalue = 18.5'),
#  Text(586.0754716981132, 142.695, 'squared_error = -0.0\nsamples = 1\nvalue = 14.1'),
#  Text(611.5188679245283, 174.405, 'X[0] <= 1.07\nsquared_error = 0.493\nsamples = 17\nvalue = 12.888'),
#  Text(593.0943396226415, 142.695, 'X[0] <= 1.068\nsquared_error = 0.135\nsamples = 9\nvalue = 13.478'),
#  Text(584.3207547169811, 110.98500000000001, 'X[4] <= 150.25\nsquared_error = 0.028\nsamples = 6\nvalue = 13.717'),
#  Text(577.3018867924528, 79.27500000000003, 'X[3] <= 89.5\nsquared_error = 0.002\nsamples = 3\nvalue = 13.567'),
#  Text(573.7924528301887, 47.565, 'squared_error = 0.0\nsamples = 1\nvalue = 13.5'),
#  Text(580.811320754717, 47.565, 'squared_error = -0.0\nsamples = 2\nvalue = 13.6'),
#  Text(591.3396226415094, 79.27500000000003, 'X[4] <= 153.0\nsquared_error = 0.009\nsamples = 3\nvalue = 13.867'),
#  Text(587.8301886792453, 47.565, 'squared_error = 0.0\nsamples = 1\nvalue = 14.0'),
#  Text(594.8490566037736, 47.565, 'X[2] <= 97.15\nsquared_error = 0.0\nsamples = 2\nvalue = 13.8'),
#  Text(591.3396226415094, 15.855000000000018, 'squared_error = 0.0\nsamples = 1\nvalue = 13.8'),
#  Text(598.3584905660377, 15.855000000000018, 'squared_error = 0.0\nsamples = 1\nvalue = 13.8'),
#  Text(601.867924528302, 110.98500000000001, 'X[2] <= 93.5\nsquared_error = 0.007\nsamples = 3\nvalue = 13.0'),
#  Text(598.3584905660377, 79.27500000000003, 'squared_error = 0.0\nsamples = 1\nvalue = 13.1'),
#  Text(605.377358490566, 79.27500000000003, 'X[2] <= 96.65\nsquared_error = 0.002\nsamples = 2\nvalue = 12.95'),
#  Text(601.867924528302, 47.565, 'squared_error = 0.0\nsamples = 1\nvalue = 12.9'),
#  Text(608.8867924528303, 47.565, 'squared_error = 0.0\nsamples = 1\nvalue = 13.0'),
#  Text(629.9433962264151, 142.695, 'X[0] <= 1.071\nsquared_error = 0.064\nsamples = 8\nvalue = 12.225'),
#  Text(622.9245283018868, 110.98500000000001, 'X[3] <= 97.7\nsquared_error = 0.012\nsamples = 5\nvalue = 12.4'),
#  Text(619.4150943396227, 79.27500000000003, 'X[1] <= 80.5\nsquared_error = 0.003\nsamples = 4\nvalue = 12.45'),
#  Text(615.9056603773585, 47.565, 'squared_error = 0.0\nsamples = 2\nvalue = 12.5'),
#  Text(622.9245283018868, 47.565, 'X[1] <= 87.3\nsquared_error = 0.0\nsamples = 2\nvalue = 12.4'),
#  Text(619.4150943396227, 15.855000000000018, 'squared_error = 0.0\nsamples = 1\nvalue = 12.4'),
#  Text(626.433962264151, 15.855000000000018, 'squared_error = 0.0\nsamples = 1\nvalue = 12.4'),
#  Text(626.433962264151, 79.27500000000003, 'squared_error = -0.0\nsamples = 1\nvalue = 12.2'),
#  Text(636.9622641509434, 110.98500000000001, 'X[2] <= 92.65\nsquared_error = 0.016\nsamples = 3\nvalue = 11.933'),
#  Text(633.4528301886793, 79.27500000000003, 'squared_error = 0.0\nsamples = 1\nvalue = 12.1'),
#  Text(640.4716981132076, 79.27500000000003, 'X[0] <= 1.072\nsquared_error = 0.003\nsamples = 2\nvalue = 11.85'),
#  Text(636.9622641509434, 47.565, 'squared_error = 0.0\nsamples = 1\nvalue = 11.9'),
#  Text(643.9811320754717, 47.565, 'squared_error = -0.0\nsamples = 1\nvalue = 11.8'),
#  Text(749.2641509433962, 301.245, 'X[0] <= 1.082\nsquared_error = 9.717\nsamples = 46\nvalue = 8.12'),
#  Text(700.1320754716982, 269.53499999999997, 'X[0] <= 1.077\nsquared_error = 1.469\nsamples = 28\nvalue = 9.736'),
#  Text(672.0566037735849, 237.825, 'X[0] <= 1.074\nsquared_error = 0.291\nsamples = 13\nvalue = 10.892'),
#  Text(658.0188679245283, 206.115, 'X[0] <= 1.073\nsquared_error = 0.071\nsamples = 7\nvalue = 11.329'),
#  Text(651.0, 174.405, 'X[1] <= 88.1\nsquared_error = 0.018\nsamples = 5\nvalue = 11.48'),
#  Text(647.4905660377359, 142.695, 'X[0] <= 1.073\nsquared_error = 0.007\nsamples = 4\nvalue = 11.425'),
#  Text(643.9811320754717, 110.98500000000001, 'squared_error = 0.0\nsamples = 2\nvalue = 11.5'),
#  Text(651.0, 110.98500000000001, 'X[3] <= 94.25\nsquared_error = 0.003\nsamples = 2\nvalue = 11.35'),
#  Text(647.4905660377359, 79.27500000000003, 'squared_error = 0.0\nsamples = 1\nvalue = 11.4'),
#  Text(654.5094339622642, 79.27500000000003, 'squared_error = -0.0\nsamples = 1\nvalue = 11.3'),
#  Text(654.5094339622642, 142.695, 'squared_error = -0.0\nsamples = 1\nvalue = 11.7'),
#  Text(665.0377358490566, 174.405, 'X[3] <= 93.5\nsquared_error = 0.002\nsamples = 2\nvalue = 10.95'),
#  Text(661.5283018867925, 142.695, 'squared_error = 0.0\nsamples = 1\nvalue = 11.0'),
#  Text(668.5471698113208, 142.695, 'squared_error = 0.0\nsamples = 1\nvalue = 10.9'),
#  Text(686.0943396226415, 206.115, 'X[0] <= 1.075\nsquared_error = 0.068\nsamples = 6\nvalue = 10.383'),
#  Text(679.0754716981132, 174.405, 'X[0] <= 1.074\nsquared_error = 0.01\nsamples = 2\nvalue = 10.7'),
#  Text(675.566037735849, 142.695, 'squared_error = 0.0\nsamples = 1\nvalue = 10.8'),
#  Text(682.5849056603773, 142.695, 'squared_error = 0.0\nsamples = 1\nvalue = 10.6'),
#  Text(693.1132075471698, 174.405, 'X[1] <= 88.75\nsquared_error = 0.022\nsamples = 4\nvalue = 10.225'),
#  Text(689.6037735849056, 142.695, 'X[4] <= 171.5\nsquared_error = 0.007\nsamples = 3\nvalue = 10.3'),
#  Text(686.0943396226415, 110.98500000000001, 'squared_error = 0.0\nsamples = 1\nvalue = 10.2'),
#  Text(693.1132075471698, 110.98500000000001, 'X[3] <= 101.85\nsquared_error = 0.002\nsamples = 2\nvalue = 10.35'),
#  Text(689.6037735849056, 79.27500000000003, 'squared_error = 0.0\nsamples = 1\nvalue = 10.4'),
#  Text(696.622641509434, 79.27500000000003, 'squared_error = -0.0\nsamples = 1\nvalue = 10.3'),
#  Text(696.622641509434, 142.695, 'squared_error = 0.0\nsamples = 1\nvalue = 10.0'),
#  Text(728.2075471698114, 237.825, 'X[0] <= 1.079\nsquared_error = 0.326\nsamples = 15\nvalue = 8.733'),
#  Text(714.1698113207548, 206.115, 'X[0] <= 1.078\nsquared_error = 0.114\nsamples = 8\nvalue = 9.175'),
#  Text(707.1509433962265, 174.405, 'X[0] <= 1.077\nsquared_error = 0.01\nsamples = 4\nvalue = 9.5'),
#  Text(703.6415094339623, 142.695, 'squared_error = 0.0\nsamples = 2\nvalue = 9.6'),
#  Text(710.6603773584906, 142.695, 'squared_error = -0.0\nsamples = 2\nvalue = 9.4'),
#  Text(721.1886792452831, 174.405, 'X[3] <= 100.05\nsquared_error = 0.008\nsamples = 4\nvalue = 8.85'),
#  Text(717.6792452830189, 142.695, 'squared_error = -0.0\nsamples = 3\nvalue = 8.8'),
#  Text(724.6981132075472, 142.695, 'squared_error = -0.0\nsamples = 1\nvalue = 9.0'),
#  Text(742.2452830188679, 206.115, 'X[0] <= 1.08\nsquared_error = 0.091\nsamples = 7\nvalue = 8.229'),
#  Text(735.2264150943397, 174.405, 'X[0] <= 1.08\nsquared_error = 0.012\nsamples = 4\nvalue = 8.475'),
#  Text(731.7169811320755, 142.695, 'X[4] <= 166.375\nsquared_error = 0.002\nsamples = 3\nvalue = 8.533'),
#  Text(728.2075471698114, 110.98500000000001, 'squared_error = 0.0\nsamples = 2\nvalue = 8.5'),
#  Text(735.2264150943397, 110.98500000000001, 'squared_error = -0.0\nsamples = 1\nvalue = 8.6'),
#  Text(738.7358490566038, 142.695, 'squared_error = 0.0\nsamples = 1\nvalue = 8.3'),
#  Text(749.2641509433962, 174.405, 'X[0] <= 1.081\nsquared_error = 0.007\nsamples = 3\nvalue = 7.9'),
#  Text(745.7547169811321, 142.695, 'squared_error = 0.0\nsamples = 1\nvalue = 8.0'),
#  Text(752.7735849056604, 142.695, 'X[1] <= 82.75\nsquared_error = 0.002\nsamples = 2\nvalue = 7.85'),
#  Text(749.2641509433962, 110.98500000000001, 'squared_error = 0.0\nsamples = 1\nvalue = 7.9'),
#  Text(756.2830188679245, 110.98500000000001, 'squared_error = 0.0\nsamples = 1\nvalue = 7.8'),
#  Text(798.3962264150944, 269.53499999999997, 'X[2] <= 107.35\nsquared_error = 12.164\nsamples = 18\nvalue = 5.606'),
#  Text(794.8867924528303, 237.825, 'X[0] <= 1.089\nsquared_error = 4.215\nsamples = 17\nvalue = 4.912'),
#  Text(775.5849056603773, 206.115, 'X[0] <= 1.084\nsquared_error = 0.394\nsamples = 10\nvalue = 6.34'),
#  Text(763.3018867924528, 174.405, 'X[1] <= 79.75\nsquared_error = 0.143\nsamples = 4\nvalue = 6.95'),
#  Text(759.7924528301887, 142.695, 'squared_error = 0.0\nsamples = 2\nvalue = 6.6'),
#  Text(766.811320754717, 142.695, 'X[3] <= 96.3\nsquared_error = 0.04\nsamples = 2\nvalue = 7.3'),
#  Text(763.3018867924528, 110.98500000000001, 'squared_error = 0.0\nsamples = 1\nvalue = 7.5'),
#  Text(770.3207547169811, 110.98500000000001, 'squared_error = 0.0\nsamples = 1\nvalue = 7.1'),
#  Text(787.867924528302, 174.405, 'X[0] <= 1.086\nsquared_error = 0.149\nsamples = 6\nvalue = 5.933'),
#  Text(780.8490566037736, 142.695, 'X[0] <= 1.085\nsquared_error = 0.017\nsamples = 4\nvalue = 6.175'),
#  Text(777.3396226415094, 110.98500000000001, 'squared_error = 0.0\nsamples = 2\nvalue = 6.3'),
#  Text(784.3584905660377, 110.98500000000001, 'X[3] <= 100.65\nsquared_error = 0.002\nsamples = 2\nvalue = 6.05'),
#  Text(780.8490566037736, 79.27500000000003, 'squared_error = 0.0\nsamples = 1\nvalue = 6.1'),
#  Text(787.867924528302, 79.27500000000003, 'squared_error = 0.0\nsamples = 1\nvalue = 6.0'),
#  Text(794.8867924528303, 142.695, 'X[0] <= 1.087\nsquared_error = 0.063\nsamples = 2\nvalue = 5.45'),
#  Text(791.377358490566, 110.98500000000001, 'squared_error = 0.0\nsamples = 1\nvalue = 5.7'),
#  Text(798.3962264150944, 110.98500000000001, 'squared_error = -0.0\nsamples = 1\nvalue = 5.2'),
#  Text(814.1886792452831, 206.115, 'X[4] <= 126.625\nsquared_error = 2.596\nsamples = 7\nvalue = 2.871'),
#  Text(805.4150943396227, 174.405, 'X[0] <= 1.104\nsquared_error = 0.122\nsamples = 2\nvalue = 0.35'),
#  Text(801.9056603773586, 142.695, 'squared_error = 0.0\nsamples = 1\nvalue = 0.7'),
#  Text(808.9245283018868, 142.695, 'squared_error = 0.0\nsamples = 1\nvalue = 0.0'),
#  Text(822.9622641509434, 174.405, 'X[0] <= 1.091\nsquared_error = 0.026\nsamples = 5\nvalue = 3.88'),
#  Text(815.9433962264151, 142.695, 'X[0] <= 1.09\nsquared_error = 0.007\nsamples = 3\nvalue = 4.0'),
#  Text(812.433962264151, 110.98500000000001, 'squared_error = 0.0\nsamples = 1\nvalue = 4.1'),
#  Text(819.4528301886793, 110.98500000000001, 'X[2] <= 85.5\nsquared_error = 0.003\nsamples = 2\nvalue = 3.95'),
#  Text(815.9433962264151, 79.27500000000003, 'squared_error = 0.0\nsamples = 1\nvalue = 4.0'),
#  Text(822.9622641509434, 79.27500000000003, 'squared_error = -0.0\nsamples = 1\nvalue = 3.9'),
#  Text(829.9811320754717, 142.695, 'X[1] <= 76.8\nsquared_error = 0.0\nsamples = 2\nvalue = 3.7'),
#  Text(826.4716981132076, 110.98500000000001, 'squared_error = 0.0\nsamples = 1\nvalue = 3.7'),
#  Text(833.4905660377359, 110.98500000000001, 'squared_error = 0.0\nsamples = 1\nvalue = 3.7'),
#  Text(801.9056603773586, 237.825, 'squared_error = -0.0\nsamples = 1\nvalue = 17.4')]

# %%
path = reg.cost_complexity_pruning_path(X_train,y_train)
ccp_alpha = path.ccp_alphas

# %%
alphalist = []
for i in range(len(ccp_alpha)):
    reg = DecisionTreeRegressor(ccp_alpha=ccp_alpha[i])
    reg.fit(X_train,y_train)
    alphalist.append(reg)

# %%
trainscore = [alphalist[i].score(X_train,y_train) for i in range(len(alphalist))]

testscore = [alphalist[i].score(X_test,y_test) for i in range(len(alphalist))]

plt.xlabel('alpha')
plt.ylabel('accuracy')
plt.plot(ccp_alpha,trainscore,marker = 'o',label = 'training',color = 'magenta',drawstyle = 'steps-post')
plt.plot(ccp_alpha,testscore,marker = '+',label = 'testing',color = 'red',drawstyle = 'steps-post')
plt.legend()
plt.show()

# %%
## normal approach

clf = DecisionTreeRegressor(ccp_alpha=1)
clf.fit(X_train,y_train)
y_pred = clf.predict(X_test)
print(f' Decision Tree Normal Approach : {metrics.r2_score(y_test,y_pred)}')


rf = RandomForestRegressor(n_estimators=1000,ccp_alpha=1)
rf.fit(X_train,y_train)
y_pred_rf = rf.predict(X_test)
print(f' Random Forest Normal Approach : {metrics.r2_score(y_test,y_pred_rf)}')
# Out:
#  Decision Tree Normal Approach : 0.9496151622616432
#  Random Forest Normal Approach : 0.9875538205441564

# %% [markdown]
# ## Hyperparameter Tuning

# %%
params = {
    'RandomForest':{
        'model': RandomForestRegressor(),
        'params':{
            'n_estimators': [int(x) for x in np.linspace(start=1,stop=1200,num=10)],
            'criterion' : ["mse", "mae"],
            'max_depth':[int(x) for x in np.linspace(start=1,stop=30,num=5)],
            'min_samples_split':[2,5,10,12],
            'min_samples_leaf':[2,5,10,12],
            'max_features':['auto','sqrt'],
            'ccp_alpha':[1,2,2.5,3,3.5,4,5],
        }
    },
    
    'D-tree':{
        'model':DecisionTreeRegressor(),
        'params':{
            'criterion':["mse", "mae"],
            'splitter':['best','random'],
            'min_samples_split':[1,2,5,10,12],
            'min_samples_leaf':[1,2,5,10,12],
            'max_features':['auto','sqrt'],
            'ccp_alpha':[1,2,2.5,3,3.5,4,5],
        }
    },
    'SVM':{
        'model':SVR(),
        'params':{
            'C':[0.25,0.50,0.75,1.0],
            'tol':[1e-10,1e-5,1e-4,0.025,0.50,0.75],
            'kernel':['linear', 'poly', 'rbf', 'sigmoid'],
            'max_iter':[int(x) for x in np.linspace(start=1,stop=250,num=10)],
        }
    }
}

# %%
scores = []
for modelname,mp in params.items():
    clf = RandomizedSearchCV(mp['model'],param_distributions=mp['params'],
                            cv=5,n_jobs=-1,n_iter=10,scoring='neg_mean_squared_error')
    
    clf.fit(X_train,y_train)
    scores.append({
        'model_name':modelname,
        'best_score':clf.best_score_,
        'best_estimator':clf.best_estimator_
    })

# %%
scoresdf = pd.DataFrame(scores,columns=['model_name','best_score','best_estimator'])
scoresdf
# Out:
#      model_name  best_score                                     best_estimator
# 0  RandomForest   -6.182185  (DecisionTreeRegressor(ccp_alpha=1, max_depth=...
# 1        D-tree  -17.009355  DecisionTreeRegressor(ccp_alpha=3.5, criterion...
# 2           SVM  -36.795810  SVR(C=0.5, kernel='poly', max_iter=111, tol=1e...

# %%
scores[0]['best_estimator']
# Out:
# RandomForestRegressor(ccp_alpha=1, criterion='mse', max_depth=8,
#                       max_features='sqrt', min_samples_leaf=2,
#                       min_samples_split=5, n_estimators=800)

# %%
rf = scores[0]['best_estimator']
rf.fit(X_train,y_train)

y_pred = rf.predict(X_test)

print(metrics.r2_score(y_test,y_pred))
# Out:
# 0.9469245711688787

# %%
totrainlist = np.array(totrain)
predicted = []
for i in range(len(totrainlist)):
    predicted.append(rf.predict([totrainlist[i]]))
    
totrain['Actual Result'] = test
totrain['Predicted Result'] = np.array(predicted)
totrain
# Out:
#      Density  Abdomen  Chest    Hip  Weight  Actual Result  Predicted Result
# 0     1.0708     85.2   93.1   94.5  154.25           12.3         12.223989
# 1     1.0853     83.0   93.6   98.7  173.25            6.1          8.408490
# 2     1.0414     87.9   95.8   99.2  154.00           25.3         22.682006
# 3     1.0751     86.4  101.8  101.2  184.75           10.4         11.182535
# 4     1.0340    100.0   97.3  101.9  184.25           28.7         27.096656
# ..       ...      ...    ...    ...     ...            ...               ...
# 247   1.0736     83.6   89.2   88.8  134.25           11.0         10.806121
# 248   1.0236    105.0  108.5  104.5  201.00           33.6         30.070811
# 249   1.0328    111.5  111.1  101.7  186.75           29.3         29.237446
# 250   1.0399    101.3  108.3   97.8  190.75           26.0         26.286739
# 251   1.0271    108.5  112.4  107.1  207.50           31.9         30.379398
#
# [252 rows x 7 columns]

# %%
sn.distplot(totrain['Actual Result'],label='Actual Result',hist=False,color='magenta')
sn.distplot(totrain['Predicted Result'],label='Predicted Result',hist=False,color='red')
plt.legend()
plt.plot()
# Out:
# []

# %%
# saving the model

import pickle
file = open('bodyfatmodel.pkl','wb')
pickle.dump(rf,file)
file.close()
